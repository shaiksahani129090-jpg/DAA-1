# %%
import time

# Input from user
n = int(input("Enter the number of elements: "))

arr = []
print("Enter the elements:")
for i in range(n):
    arr.append(int(input()))

# Start execution time
start_time = time.perf_counter()

# Bubble Sort
for i in range(n - 1):
    swapped = False
    for j in range(n - i - 1):
        if arr[j] > arr[j + 1]:
            arr[j], arr[j + 1] = arr[j + 1], arr[j]
            swapped = True

    if not swapped:
        break

# End execution time
end_time = time.perf_counter()

# Calculate execution time
execution_time = (end_time - start_time) * 1_000_000  # Convert to microseconds

# Display sorted array
print("\nSorted Array:")
print(arr)

# Display execution time
print(f"\nExecution Time: {execution_time:.2f} microseconds")

# Display time complexity
print("\nTime Complexity:")
print("Best Case    : O(n)")
print("Average Case : O(n^2)")
print("Worst Case   : O(n^2)")
# Out:
# Enter the number of elements:  5
# Enter the elements:
#  15
#  1
#  40
#  3
#  25
# Sorted Array:
# [1, 3, 15, 25, 40]
#
# Execution Time: 441.90 microseconds
#
# Time Complexity:
# Best Case    : O(n)
# Average Case : O(n^2)
# Worst Case   : O(n^2)

# %%
import time

# Function to perform partition
def partition(arr, low, high):
    pivot = arr[high]
    i = low - 1

    for j in range(low, high):
        if arr[j] <= pivot:
            i += 1
            arr[i], arr[j] = arr[j], arr[i]

    arr[i + 1], arr[high] = arr[high], arr[i + 1]
    return i + 1

# Function to perform Quick Sort
def quick_sort(arr, low, high):
    if low < high:
        pi = partition(arr, low, high)

        quick_sort(arr, low, pi - 1)
        quick_sort(arr, pi + 1, high)

# Main Program
n = int(input("Enter the number of elements: "))

arr = []
print("Enter the elements:")
for i in range(n):
    arr.append(int(input()))

# Start execution time
start_time = time.perf_counter()

# Quick Sort
quick_sort(arr, 0, n - 1)

# End execution time
end_time = time.perf_counter()

# Calculate execution time
execution_time = (end_time - start_time) * 1_000_000  # Convert to microseconds

# Display sorted array
print("\nSorted Array:")
print(arr)

# Display execution time
print(f"\nExecution Time: {execution_time:.2f} microseconds")

# Display time complexity
print("\nTime Complexity:")
print("Best Case    : O(n log n)")
print("Average Case : O(n log n)")
print("Worst Case   : O(n^2)")
# Out:
# Enter the number of elements:  5
# Enter the elements:
#  15
#  20
#  3
#  48
#  10
# Sorted Array:
# [3, 10, 15, 20, 48]
#
# Execution Time: 191.60 microseconds
#
# Time Complexity:
# Best Case    : O(n log n)
# Average Case : O(n log n)
# Worst Case   : O(n^2)

# %%
import time

# Input from user
n = int(input("Enter the number of elements: "))

arr = []
print("Enter the elements:")
for i in range(n):
    arr.append(int(input()))

# Start execution time
start_time = time.perf_counter()

# Insertion Sort
for i in range(1, n):
    key = arr[i]
    j = i - 1

    while j >= 0 and arr[j] > key:
        arr[j + 1] = arr[j]
        j -= 1

    arr[j + 1] = key

# End execution time
end_time = time.perf_counter()

# Calculate execution time
execution_time = (end_time - start_time) * 1_000_000  # Convert to microseconds

# Display sorted array
print("\nSorted Array:")
print(arr)

# Display execution time
print(f"\nExecution Time: {execution_time:.2f} microseconds")

# Display time complexity
print("\nTime Complexity:")
print("Best Case    : O(n)")
print("Average Case : O(n^2)")
print("Worst Case   : O(n^2)")
# Out:
# Enter the number of elements:  5
# Enter the elements:
#  10
#  25
#  -6
#  0
#  4
# Sorted Array:
# [-6, 0, 4, 10, 25]
#
# Execution Time: 323.60 microseconds
#
# Time Complexity:
# Best Case    : O(n)
# Average Case : O(n^2)
# Worst Case   : O(n^2)

# %%
import time

# Input from user
n = int(input("Enter the number of elements: "))

arr = []
print("Enter the elements:")
for i in range(n):
    arr.append(int(input()))

# Start execution time
start_time = time.perf_counter()

# Selection Sort
for i in range(n):
    min_index = i

    for j in range(i + 1, n):
        if arr[j] < arr[min_index]:
            min_index = j

    # Swap the minimum element with the first unsorted element
    arr[i], arr[min_index] = arr[min_index], arr[i]

# End execution time
end_time = time.perf_counter()

# Calculate execution time
execution_time = (end_time - start_time) * 1_000_000  # Convert to microseconds

# Display sorted array
print("\nSorted Array:")
print(arr)

# Display execution time
print(f"\nExecution Time: {execution_time:.2f} microseconds")

# Display time complexity
print("\nTime Complexity:")
print("Best Case    : O(n^2)")
print("Average Case : O(n^2)")
print("Worst Case   : O(n^2)")
# Out:
# Enter the number of elements:  5
# Enter the elements:
#  -9
#  21
#  3
#  45
#  20
# Sorted Array:
# [-9, 3, 20, 21, 45]
#
# Execution Time: 481.10 microseconds
#
# Time Complexity:
# Best Case    : O(n^2)
# Average Case : O(n^2)
# Worst Case   : O(n^2)

# %%
import time

# Merge Sort Function
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2

        left = arr[:mid]
        right = arr[mid:]

        # Recursive calls
        merge_sort(left)
        merge_sort(right)

        i = j = k = 0

        # Merge the two halves
        while i < len(left) and j < len(right):
            if left[i] < right[j]:
                arr[k] = left[i]
                i += 1
            else:
                arr[k] = right[j]
                j += 1
            k += 1

        # Copy remaining elements of left[]
        while i < len(left):
            arr[k] = left[i]
            i += 1
            k += 1

        # Copy remaining elements of right[]
        while j < len(right):
            arr[k] = right[j]
            j += 1
            k += 1


# Main Program
n = int(input("Enter the number of elements: "))

arr = []
print("Enter the elements:")
for i in range(n):
    arr.append(int(input()))

# Start execution time
start_time = time.perf_counter()

# Perform Merge Sort
merge_sort(arr)

# End execution time
end_time = time.perf_counter()

# Calculate execution time
execution_time = (end_time - start_time) * 1_000_000  # Convert to microseconds

# Display sorted array
print("\nSorted Array:")
print(arr)

# Display execution time
print(f"\nExecution Time: {execution_time:.2f} microseconds")

# Display time complexity
print("\nTime Complexity:")
print("Best Case    : O(n log n)")
print("Average Case : O(n log n)")
print("Worst Case   : O(n log n)")
# Out:
# Enter the number of elements:  5
# Enter the elements:
#  24
#  30
#  -80
#  200
#  45
# Sorted Array:
# [-80, 24, 30, 45, 200]
#
# Execution Time: 250.40 microseconds
#
# Time Complexity:
# Best Case    : O(n log n)
# Average Case : O(n log n)
# Worst Case   : O(n log n)
